# %% [markdown]
# ## Bonus Question
#
# ### Periodic signals
#
# 1. $x[𝑛] = \cos (1.2\pi 𝑛)$
# 2. $𝑦(𝑡) = \cos(2𝑡 − \pi)$
# 3. $𝑦[n] = \cos(2n − \pi)$
# 4. $𝑧[𝑛] = (−1) ^n$
#
# ### Aperiodic signals
#
# 1. $𝑥 ( 𝑡 ) = \cos (1.2\pi 𝑡)𝑢(𝑡)$
# 2. $z(t) = e ^{-t} \cos (2t)$

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import math
import numpy as np

n = np.linspace(-5, 5, 100)

# %% [markdown]
# $x[𝑛] = \cos (1.2\pi 𝑛)$

# %%
x1 = np.cos(1.2 * np.pi * n)

plt.figure(figsize=(10, 8))
plt.stem(n, x1)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# $𝑦(𝑡) = \cos(2𝑡 − \pi)$

# %%
y1 = np.cos(2 * n - np.pi)

plt.figure(figsize=(10, 8))
plt.plot(n, y1)

# %% [markdown]
# $𝑦[n] = \cos(2n − \pi)$

# %%
y2 = np.cos(2 * n - np.pi)

plt.figure(figsize=(10, 8))
plt.stem(n, y2)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# $𝑧[𝑛] = (−1) ^n$

# %%
n1 = np.linspace(-10, 10, 1000)
z1 = np.power(-1, n + 0j)

plt.figure(figsize=(12, 8))
plt.stem(n, z1)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# $𝑥 ( 𝑡 ) = \cos (1.2\pi 𝑡)𝑢(𝑡)$

# %%
u = np.heaviside(n, 1)
x2 = np.cos(1.2 * np.pi * n) * u

plt.figure(figsize=(10, 8))
plt.plot(n, x2)

# %% [markdown]
# $z(t) = e ^{-t} \cos (2t)$

# %%
z2 = np.e ** (-n) * np.cos(2 * n)

plt.figure(figsize=(10, 8))
plt.plot(n, z2)
